# %% [markdown]
# # **Presentation Script**

# %% [markdown]
# #Page1.
# * 안녕하십니까 코드스테이츠 AI_18기 주형진입니다.
# 오늘은 다음 분기에 출시할 게임의 설계방향에 대하여 데이터를 탐구하고 분석하여 결론을 도출 할 것이고, 지역과 장르 그리고 플랫폼의 관점을 고려하여 접근할 것입니다.

# %% [markdown]
# #Page2
# * Part0 에서는 프로토타입의 데이터를 탐색적 데이터 분석과 피쳐엔지니어링을 통해 간단하게 시행합니다.
# * Part1 에서는 지역별 & 출고량과 장르 선호도를 살펴보고
# * Part2 에서는 연도별 & 시대별 장르출고량과 & 비율 트렌드와 함께 시대별 주목할만한 트렌드 게임 몇가지를.
# * Part3 에서는 인기가 많은 게임의 특징을
# * Part4 에서는 주요 지역 플랫폼 비율, 플랫폼별 출고량을 살펴봅니다.

# %% [markdown]
# #Page3
# * 스크립트가 없습니다.

# %% [markdown]
# #Page4
# * 다음은 데이터 프레임 초기 모습입니다.
# * Unnamed 라는 컬럼을 보니, 이전 형태에서 index번호를 겹쳐서 저장된 모습입니다.
# * 삭제를 진행했습니다.
# * 그리고 Year Column을 보면 정수형이 아닌 실수형으로 표기된 모습이 보이는데
# * 이 부분도 수정했습니다.

# %% [markdown]
# #Page5
# * 타이틀명으로 중복되는 값들이 있나 검색을해보았는데, 타이틀명이 중복되는 경우는 이름은 같지만 다른 플랫폼으로 출시된 게임들이었습니다.

# %% [markdown]
# #Page6
# * Year Column의 결측치는 271개로 전체 데이터수 에 비해서 미치는 영향이 미미하다고 생각했고,
# * 지역과 장르 값이 남아있으면 의미 도출이 가능하다고 보아
# * 수치계산을 쉽게하기 위해 결측값들을 0으로 대체하였습니다.
# * 밑에 초록색표시한 부분은 최종적으로 Year Column이 수정된 모습입니다.

# %% [markdown]
# #Page7
# * 다음은 장르 결측치를 갖고 있는 데이터들의 모습입니다.
# * 장르 결측치가 있는 데이터는 분석에 도움이 되지 않는다고 생각했고 그 수도 50개로 전체에 데이터수에 비해 매우 적으므로 삭제 하기로 했습니다.

# %% [markdown]
# #Page8
# * 다음은 Sales_Column 들에 통일 되지 않은 단위들이 많이 보입니다.
# * 외부 데이터를 대조해 추정결과 M은 밀리언으로 파악했고,
# * 숫자만 있는 부분은 이 단위가 생략된 것이고
# * K가 포함된 문자열은 K를 제거하고 1000으로 나누어 단위를 통일 했습니다.
# * M이 포함된 문자열은 간단히 M을 제거하였고
# * Sales_Column 전체를 기존의 문자열 타입에서 실수형타입으로 바꾸어주었습니다.

# %% [markdown]
# #Page9
# * 현재 화면에 하이라이트된 부분은 지역에 대한 데이터 분석전
# * 토탈 세일즈라고 해서 전지역 컬럼값들을 모두 더해 총출고량 컬럼을 만들어 주었습니다.

# %% [markdown]
# #Page10
# * 스크립트가 없습니다.

# %% [markdown]
# #Page11
# * 지역은 (북미,유럽,일본,그외)로 4개 지역으로 구분하였고, 다음은 지역에 따른 장르들의 출고량 그래프입니다.
# * 일본을 제외한 북미와 유럽 그리고 그외 인 3개 지역에서는 공통적으로 (액션,스포츠,슈터) 장르순으로 인기가 있었습니다.
# * 북미와 유럽을 제외한 다른나라들도 북미와 유럽의 양상을 따라갔으나
# * 일본만 특이한 양상을 보였는데, 일본에서는 롤플레잉이 가장 선호되는 장르였습니다.
# * 그리고 일본에서는 모든 지역에서 3위권을 기록하고 있는 슈터 장르가 12위권으로 인기 최하위권을 기록하고 있었습니다.

# %% [markdown]
# #Page12
# * 지역별로 선호하는 게임의 장르가 같은지 다른지 생각해보면
# * 전체 지역이 북미,유럽 서구의 트렌드를 강력하게 따라 가고 있고,
# * 일본만 다른 추이를 보이는데. 그 원인중 하나는 서구 사회와 일본 사회의 문화적 측면으로 볼 수 있습니다.
# * 서양의 개인주의와 경쟁, 독립,행동 들을 우선시 하는 문화와 달리(빠른반응,대전액션,서바이벌,경쟁)
# * 일본문화는 그룹의 전체적인 하모니, 커뮤니티, 협동추구,스토리텔링에 좀 더 중점을 둡니다.
# * 이런점들이 일본에서 롤플레잉 장르(정적이고 내러티브, 캐릭터육성, 탐구,설명 등에 더 중점을 둔)가 인기 있는 이유라고 봅니다.

# %% [markdown]
# #Page13
# * 스크립트가 없습니다.

# %% [markdown]
# #Page14
# * 다음은 연도별 분석전 Year column 이상치 처리입니다.
# * Year column에 이상치들을 처리하기위해 히스토그램을 사용하였고
# * 1980년 이하의 데이터들을 이상치로 간주하고 제거하기로 했습니다.

# %% [markdown]
# #Page15
# * 트렌드는 년도별/시대별 장르들의 총 출고량을 기준으로 판단하기로 했습니다.
# * 다음은 년도별 총출고량을 장르에 따라 시각화한 모습입니다.
# * 12개의 그래프를 한번에 담은 시각화는 매우 복잡하여
# * 12개로 분리시켜 재시각화 하였습니다.
# * 그리고 10년 단위로 나누어서, 각 시대별 각 장르가 차지하는 비율을 파이차트로 그려 분석했습니다.

# %% [markdown]
# #Page16
# * 2015년 이후로 전체 장르의 총출고량이 감소하는 추세를 보이며, 앞으로 어떤 구간이 상승세를 탈지는 예측하기 어렵습니다.
# * 초록색 부분은 구간 전체 평균값과 최고점의 차이가 가장 컸던 장르들입니다.

# %% [markdown]
# #Page17
# * 시대를 10년 단위로 (decade) 구분하고 그에 따른 장르별 비율을 파이차트로 시각화 한 모습입니다.
# * 시간에 흐름에 따라 각 시점관찰 데이터와 10년전 데이터의 장르별 비율을 비교해보도록 합니다.

# %% [markdown]
# #Page18
# * 80년대는 플랫폼의 전성시대라고 볼 수 있습니다.
# * 퍼즐이라는 장르도 매우 큰 비중을 차지 하고 있습니다.
# * 반면에 롤플레잉과 레이싱은 미미한 수준입니다.

# %% [markdown]
# #Page19
# * 차트입니다. 80년대와 비교하면 플랫폼의 비중이 거의 절반 가량 줄어들고
# * 롤플레잉이 거의 3배이상 늘었습니다. 퍼즐장르도 80년대 대비 90년대 차지하는 비율의 수치가 1/5로 매우 급격하게 줄어들었습니다.
# * 격투게임도 상당히 증가한 모습을 보입니다.

# %% [markdown]
# #Page20
# * 플랫폼은 90년대 대비 (수치가 8.1로) 거의 절반가량 비율이 줄어들며 급격한 하락세가 계속 되고 있습니다.
# * 90년대에 급격하게 증가했던 롤플레잉도 약간 감소하고 있고, 액션,스포츠,슈터의 비율이 증가하면서 3개의 영역이 상위권으로 자리잡는 모습이 보입니다.
# * Misc 장르가 2000년대에는 2배이상 증가한 부분이 특징입니다.

# %% [markdown]
# #Page21
# * 2010년대는 액션,슈터,스포츠 이 세개의 영역이 1,2,3위를 하면서 확실한 자리를 잡았고, 플랫폼 비율은 더더욱 감소하여 마이너한 비율을 차지하게 되었습니다.

# %% [markdown]
# #Page22
# * 다음은 80년대 트랜디 했던 인기 타이틀입니다.
# * 장르는 둘다 플랫폼으로 동키콩과 수퍼마리오브로스가있습니다.

# %% [markdown]
# #Page23
# * 다음은 90년대 트렌디 했던 인기 타이틀입니다.
# * 롤플레잉에는 파이널판타지7과 디아블로, 레이싱게임에는 니드포스피드가 있습니다.

# %% [markdown]
# #Page24
# * 다음은 2000년대 입니다.
# * 액션엔 GTA 산안드레아스, 슈터에는 헤일로2,콜오브듀티4, 스포츠게임에는 피파09입니다.

# %% [markdown]
# #Page25
# * 2010년
# * 액션은 라스트오브어스, 슈터는 콜오브듀티 모던워페어3, 스포츠에는 피파15입니다.

# %% [markdown]
# #Page26
# # 왜 이러한 트렌드와 양상을 보였냐고 생각하냐면
# * 게임의 역사가 얼마 되지 않은 초창기에는 기술의 발전도 부족했고
# * 게임에 대한 유저들의 이해와 숙련도도 상당히 낮은 편이기 때문에
# * 비교적 컨트롤과 플레잉이 쉽고 단순한 플랫폼 베이스드 게임이 유행했다고 생각합니다.
# * 이와 더불어 시간이 지남에 따라 컴퓨터 3D그래픽 기술의 눈부신 발전과 함께
# * 빠른 반응속도와 프레임들 구현이 가능하고,
# * 거대해진 게임 시장과 더불어 유저들의 숙련도도 발전하고 점점 더 자극적이고 즉각적이고,
# * 다이나믹한 게임을 추구하게 되면서 현재의 행보가 마련되었다고 생각합니다.

# %% [markdown]
# #Page27
# * 인기가 많다는 기준은 총출고량이 높을 수록 인기가 많다라고 정했습니다.
# * 그 후 총출고량이 가장 높은 10개의 각 타이틀에 대해서,
# * 장르와 총출고량을 나타낸 그래프를 시각화 후
# * 그 10개의 타이틀을
# * 다시 장르별로 분류하여 총 출고량을 시각화 하였습니다.

# %% [markdown]
# #Page28
# * 다음은 10개의 각 타이틀에 대한 총출고량 그래프입니다.
# * 출고량이 가장 높은 타이틀명은
# * Wii sports 와 Super Mario Bros입니다.

# %% [markdown]
# #Page29
# * 다음은 10개의 타이틀을 장르별로 분류하여, 장르별 10개의 타이틀 총출고량을 시각화한모습입니다.
# * 스포츠장르가 1위 였고
# * 플랫폼이2위 였습니다.

# %% [markdown]
# #Page30
# * 다음은 역대 출고량이 가장 많았던 게임들입니다.
# * 이 게임들이 왜 인기가 많다고 생각하냐면 ->
# * 1위 Wii sports는 우선 타겟 유저층의 범위가 매우 넓습니다.
# 초보자도 쉽게 접하고 입문 할 수 있는 것이 스포츠 장르이고, 매니아적인 컨셉이나 배경,설정을 요구하지 않아 누구나 즐기기 쉽습니다.
#    2위 Super mario Bros. 역시 초창기 플랫폼 베이스의 단순함과 쉬운 컨트롤이 유저들의 진입장벽을 낮추었다고 생각합니다.
#
# * 해당 분석을 통해 나온 인사이트는 ->
# * 게임 플레이를 단순화 하고 입문하기 쉬운 장르와 플레이 형태의 게임을 만들면
# * 폭넓은 유저들을 끌어 들일 수 있어, 더 높은 수익을 거두기 쉬울 것이다 판단하기 쉽지만
# * 단순히 총출고량이 가장 높았던 스포츠나 플랫폼 베이스를 장르로 선택하지 않고,
# * 연도별, 시대별 흐름도 고려하여 결정하기로 했습니다.
# <!-- (* 장르는 총출고량만 보았을 때는 스포츠와 플랫폼이 압도적이나 플랫폼 장르는 90년대 이후로 거의 소멸해가고, 스포츠 역시 1위는 아니기 때문에 (2010년대는 3위) 잠정적 후보로만 두도록 했습니다.
#    * 플랫폼에서는 총출고량 상위권을 기록한 Wii와 Nintendo가 아닌 시대별 총플랫폼 비중의 대부분을 차지하는 Playstation 시리즈와 Xbox360 계열 중 하나를 출시 플랫폼으로 정하기로 했습니다. ) -->

# %% [markdown]
# #Page31
# * 우선 트렌드를 선도하는 북미와 유럽에서 가장많이 팔리는 플랫폼 2개를 조사하고, 전체 지역에서 가장 많이 팔리는 플랫폼 2개를 조사하기로 했습니다.

# %% [markdown]
# #Page32
# * 다음은 북미 플랫폼 출고 점유율입니다.
# * 엑스박스360, 플레이스테이션2 순으로 높은 점유율을 차지하고 있습니다.

# %% [markdown]
# #Page33
# * 다음은 유럽 플랫폼 출고 점유율입니다.
# * 플레이스테이션3, 플레이스테이션2,엑스박스360 순으로 높은 점유율을 차지하고 있습니다.

# %% [markdown]
# #Page34
# * 다음은 플랫폼별 전지역 출고량 그래프입니다.
# * 플레이스테이션2가 압도적인 1위를 차지 하고 있습니다.
# * 엑스박스가 그 뒤를 따라오는 모습입니다.

# %% [markdown]
# #Page35
# * 다음은 시대별로 구분하여
# * 출고되었던 플랫폼들의 총출고량을 시각화한 모습입니다.
# * 역시 한번에 시각화하면 눈으로 분석하기가 힘들어
# * 다음과 같이 시대별로 그래프를 4가지로 나누었습니다.

# %% [markdown]
# #Page36
# * 우선 80년대입니다.
# * NES(닌텐도스위치엔터테인먼트사)가 압도적인 출고량으로 1위를 기록하고 있습니다.

# %% [markdown]
# #Page37
# * 90년대는 PS의 등장과함께
# * 게임 마켓 규모 자체가 2배이상으로 커졌고,
# * 플레이스테이션은 80년대 1위를 기록했던 NES와 10배이상의 격차를 보입니다.

# %% [markdown]
# #Page38
# * 2000년대 역시 PS후속작 PS2가 1위 압도적 기록했고 90년대 PS의 기록의 2배를 뛰어넘었습니다.
# * 닌텐도DS와 Wii 가 2,3위를 다투고 있고
# * 엑스박스360도 순위권에 등장했습니다.

# %% [markdown]
# #Page39
# * 2010년대는 PS3와 엑스박스360이 강력한 대립 구도를 벌이며 1,2위를 다투는 모습입니다.
# * (그외 이전의 강세였던 Wii는 출고량이 많이 하락한 모습입니다.)

# %% [markdown]
# #Page40
# * 앞에서 본 주요지역별 플랫폼 비율, 시대별 플랫폼 출고량 데이터를 종합해본 결과
# * 간단한 수치 분석을 통해 플스와 엑스박스 둘중 하나를 출시플랫폼으로 결정하기로 합니다.

# %% [markdown]
# #Page41
# * 다음은 출시된 플스와 엑스박스로 출시된 타이틀들의 총수로
# * 플레이스테이션계열의 수가 엑스박스보다 대략 4배정도 컸습니다.
# * 플레이스테이션 계열 전기종의 합으로 분류한 이유는
# * 위에서 본 시대별 데이터를 참조해볼 때, 플스는 매니아층이 많다고 생각하고 이들을 잠재적 고객으로 분류했기 때문입니다.

# %% [markdown]
# #Page42
# * 다음은 현재 까지의 플레이스테이션 출시일입니다.
# * 대략 6-7년 주기로 출시하는 것으로 볼 수 있습니다.

# %% [markdown]
# #Page43
# ##결론
# * 지금까지의 전체 데이터를 모두 분석한 결과,
# * 어떤 지역에 팔것이냐에 대해서는 전지역으로 지정하였고
# * 장르에 대해서는 전지역 공통적으로 가장 인기있는 장르 (액션,스포츠,슈터중)중에 액션으로 정하였는데
# 1. 이 이유는
# * 슈터같은경우는 정말 최정점을 찍었던 시대와 현재 출고량이 격차가 매우 크다보니 이 이상의 수치를 다시 보여주기란 힘들 것으로 판단 하였습니다.
# 2. 액션이나 스포츠중 액션을 고른 이유는
# * 2000년에서 2010년의 구간을 보면
# * 액션의 비율 유의미하게 증가했고, 스포츠의 비율은 유의미하게 감소 했습니다.
# * 따라서 **장르는 액션으로** 출시하기로 했습니다.
# 3. 마지막으로 플랫폼을 정하는데 있어서는
# * PS계열 유저를 합친 수를 고려할때 잠재적 플스 유저가 훨씬 많다고 생각해서이고,
# * 지금 상승세를 보이는 엑스박스에 대비해서 경쟁적으로
# * 새롭게 준비 할것이라 판단 하였습니다.
# 4.
# * 그래서 전체 시대적 장르비율과, 전체지역적 장르비율, 전체시대적 플랫폼비율 고려하여
# # * 새로 출시할 게임의 플랫폼은 PS로, 장르는 액션으로 출시하도록 합니다.
# # 출시 예상 년도는 6-7년 주기 발표하는 신형 PS6 플랫폼 개발에 맞추어서
# 2026-2027년 사이로
# # 지역은 전 지역을 대상으로
# # 장르는 액션으로
# # 플랫폼은 PS6으로 출시하도록 했습니다.

# %% [markdown]
# #Page44
# * 감사합니다 지금까지 AI_18기 주형진이었습니다.
